# %% [markdown]
# # Hub with Keras
#
# 富士山判別機を作るためにまずはサンプルを動かして確認
# [Hub with Keras |TensorFlow](https://www.tensorflow.org/tutorials/images/hub_with_keras)
# [TensorFlowで画像認識「〇〇判別機」を作る - Qiita](https://qiita.com/too-ai/items/4fad0239b8b3c465fe6d)

# %% [markdown]
# ## Setup

# %%
# !pip install -q tensorflow_hub

# %%
from __future__ import absolute_import, division, print_function

import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow.keras import layers

#バージョン確認
tf.VERSION
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0402 20:19:09.655478 139940478830336 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# '1.13.1'

# %% [markdown]
# ## Dataset

# %%
data_root = tf.keras.utils.get_file(
  'flower_photos','https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
   untar=True)

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
image_data = image_generator.flow_from_directory(str(data_root))
# Out:
# Found 3670 images belonging to 5 classes.

# %%
#画像バッチ形状：（32、256、256、3）
# ラベルバッチ形状：（32,5）
for image_batch,label_batch in image_data:
    print("Image batch shape: ", image_batch.shape)
    print("Labe batch shape: ", label_batch.shape)
    break
# Out:
# Image batch shape:  (32, 256, 256, 3)
# Labe batch shape:  (32, 5)

# %% [markdown]
# ## An ImageNet classifier
#  Download the classifier

# %%
classifier_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/classification/2" #@param {type:"string"}

# %%
def classifier(x):
    classifier_module = hub.Module(classifier_url)
    return classifier_module(x)
  
IMAGE_SIZE = hub.get_expected_image_size(hub.Module(classifier_url))
# Out:
# WARNING:tensorflow:From /home/class/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/control_flow_ops.py:3632: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# W0402 20:19:11.275624 139940478830336 deprecation.py:323] From /home/class/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/control_flow_ops.py:3632: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
classifier_layer = layers.Lambda(classifier, input_shape = IMAGE_SIZE+[3])
classifier_model = tf.keras.Sequential([classifier_layer])
classifier_model.summary()
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0402 20:19:17.891257 139940478830336 saver.py:1483] Saver not created because there are no variables in the graph to restore
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 1001)              0
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________

# %%
image_data = image_generator.flow_from_directory(str(data_root), target_size=IMAGE_SIZE)
for image_batch,label_batch in image_data:
    print("Image batch shape: ", image_batch.shape)
    print("Labe batch shape: ", label_batch.shape)
    break
# Out:
# Found 3670 images belonging to 5 classes.
# Image batch shape:  (32, 224, 224, 3)
# Labe batch shape:  (32, 5)

# %%
import tensorflow.keras.backend as K
sess = K.get_session()
init = tf.global_variables_initializer()

sess.run(init)

# %% [markdown]
# ## Run it on a single image

# %%
import numpy as np
import PIL.Image as Image

grace_hopper = tf.keras.utils.get_file('image.jpg','https://storage.googleapis.com/download.tensorflow.org/example_images/grace_hopper.jpg')
grace_hopper = Image.open(grace_hopper).resize(IMAGE_SIZE)
grace_hopper
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F46187FA438>

# %%
grace_hopper = np.array(grace_hopper)/255.0
grace_hopper.shape
# Out:
# (224, 224, 3)

# %%
result = classifier_model.predict(grace_hopper[np.newaxis, ...])
result.shape
# Out:
# (1, 1001)

# %%
predicted_class = np.argmax(result[0], axis=-1)
predicted_class
# Out:
# 653

# %% [markdown]
# ## Decode the predictions

# %%
labels_path = tf.keras.utils.get_file('ImageNetLabels.txt','https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
imagenet_labels = np.array(open(labels_path).read().splitlines())

# %%
plt.imshow(grace_hopper)
plt.axis('off')
predicted_class_name = imagenet_labels[predicted_class]
_ = plt.title("Prediction: " + predicted_class_name)

# %% [markdown]
# ## Run it on a batch of images

# %%
result_batch = classifier_model.predict(image_batch)

# %%
labels_batch = imagenet_labels[np.argmax(result_batch, axis=-1)]
labels_batch
# Out:
# array(['picket fence', 'toyshop', 'daisy', 'velvet', 'vase', 'cardoon',
#        'coral fungus', 'daisy', 'coral fungus', 'daisy', 'bell pepper',
#        'swab', 'cardoon', 'daisy', 'pot', 'daisy', 'pot',
#        'Bedlington terrier', 'cardoon', 'sea urchin', 'honeycomb',
#        'binder', 'bee', 'picket fence', 'bee', 'hen-of-the-woods',
#        'artichoke', 'daisy', 'garden spider', 'bee', 'vase', 'packet'],
#       dtype='<U30')

# %%
plt.figure(figsize=(10,9))
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(image_batch[n])
  plt.title(labels_batch[n])
  plt.axis('off')
_ = plt.suptitle("ImageNet predictions")

# %% [markdown]
# # Simple transfer learning

# %% [markdown]
# ## Download the headless model

# %%
feature_extractor_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/2" #@param {type:"string"}

# %%
def feature_extractor(x):
  feature_extractor_module = hub.Module(feature_extractor_url)
  return feature_extractor_module(x)

IMAGE_SIZE = hub.get_expected_image_size(hub.Module(feature_extractor_url))

# %%
image_data = image_generator.flow_from_directory(str(data_root), target_size=IMAGE_SIZE)
for image_batch,label_batch in image_data:
  print("Image batch shape: ", image_batch.shape)
  print("Labe batch shape: ", label_batch.shape)
  break
# Out:
# Found 3670 images belonging to 5 classes.
# Image batch shape:  (32, 224, 224, 3)
# Labe batch shape:  (32, 5)

# %%
features_extractor_layer = layers.Lambda(feature_extractor, input_shape=IMAGE_SIZE+[3])

# %%
features_extractor_layer.trainable = False

# %% [markdown]
# ## Attach a classification head

# %%
model = tf.keras.Sequential([
  features_extractor_layer,
  layers.Dense(image_data.num_classes, activation='softmax')
])
model.summary()
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0402 20:19:39.779471 139940478830336 saver.py:1483] Saver not created because there are no variables in the graph to restore
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 6405
# =================================================================
# Total params: 6,405
# Trainable params: 6,405
# Non-trainable params: 0
# _________________________________________________________________

# %%
init = tf.global_variables_initializer()
sess.run(init)

# %%
result = model.predict(image_batch)
result.shape
# Out:
# (32, 5)

# %% [markdown]
# ## Train the model

# %%
model.compile(
  optimizer=tf.train.AdamOptimizer(), 
  loss='categorical_crossentropy',
  metrics=['accuracy'])

# %%
class CollectBatchStats(tf.keras.callbacks.Callback):
  def __init__(self):
    self.batch_losses = []
    self.batch_acc = []
    
  def on_batch_end(self, batch, logs=None):
    self.batch_losses.append(logs['loss'])
    self.batch_acc.append(logs['acc'])

# %%
steps_per_epoch = image_data.samples//image_data.batch_size
batch_stats = CollectBatchStats()
model.fit((item for item in image_data), epochs=1, 
                    steps_per_epoch=steps_per_epoch,
                    callbacks = [batch_stats])
# Out:
# WARNING:tensorflow:From /home/class/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# W0402 20:19:49.175660 139940478830336 deprecation.py:323] From /home/class/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 114/114 [==============================] - 222s 2s/step - loss: 0.7112 - acc: 0.7336

# %%
plt.figure()
plt.ylabel("Loss")
plt.xlabel("Training Steps")
plt.ylim([0,2])
plt.plot(batch_stats.batch_losses)

plt.figure()
plt.ylabel("Accuracy")
plt.xlabel("Training Steps")
plt.ylim([0,1])
plt.plot(batch_stats.batch_acc)

# %% [markdown]
# ## Check the predictions

# %%
label_names = sorted(image_data.class_indices.items(), key=lambda pair:pair[1])
label_names = np.array([key.title() for key, value in label_names])
label_names
# Out:
# array(['Daisy', 'Dandelion', 'Roses', 'Sunflowers', 'Tulips'],
#       dtype='<U10')

# %%
result_batch = model.predict(image_batch)

labels_batch = label_names[np.argmax(result_batch, axis=-1)]
labels_batch
# Out:
# array(['Daisy', 'Tulips', 'Dandelion', 'Sunflowers', 'Tulips',
#        'Dandelion', 'Daisy', 'Roses', 'Daisy', 'Tulips', 'Sunflowers',
#        'Roses', 'Tulips', 'Dandelion', 'Tulips', 'Dandelion', 'Roses',
#        'Daisy', 'Daisy', 'Tulips', 'Daisy', 'Daisy', 'Dandelion',
#        'Tulips', 'Dandelion', 'Tulips', 'Dandelion', 'Daisy', 'Dandelion',
#        'Tulips', 'Daisy', 'Roses'], dtype='<U10')

# %%
plt.figure(figsize=(10,9))
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(image_batch[n])
  plt.title(labels_batch[n])
  plt.axis('off')
_ = plt.suptitle("Model predictions")

# %% [markdown]
# ## Export your model

# %%
export_path = tf.contrib.saved_model.save_keras_model(model, "./saved_models")
export_path
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/class/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/network.py:1436: update_checkpoint_state (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.train.CheckpointManager to manage checkpoints rather than manually editing the Checkpoint proto.
# W0402 20:23:48.742865 139940478830336 deprecation.py:323] From /home/class/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/network.py:1436: update_checkpoint_state (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.train.CheckpointManager to manage checkpoints rather than manually editing the Checkpoint proto.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0402 20:23:52.454250 139940478830336 saver.py:1483] Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:From /home/class/anaconda3/lib/python3.7/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:257: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0402 20:23:54.811332 139940478830336 deprecation.py:323] From /home/class/anaconda3/lib/python3.7/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:257: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# I0402 20:23:54.822681 139940478830336 export.py:587] Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# I0402 20:23:54.833238 139940478830336 export.py:587] Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: None
# I0402 20:23:54.839161 139940478830336 export.py:587] Signatures INCLUDED in export for Predict: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: ['train']
# I0402 20:23:54.842329 139940478830336 export.py:587] Signatures INCLUDED in export for Train: ['train']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# I0402 20:23:54.848917 139940478830336 export.py:587] Signatures INCLUDED in export for Eval: None
# WARNING:tensorflow:Export includes no default signature!
# W0402 20:23:54.850194 139940478830336 tf_logging.py:161] Export includes no default signature!
# INFO:tensorflow:No assets to save.
# I0402 20:23:56.052331 139940478830336 builder_impl.py:629] No assets to save.
# INFO:tensorflow:No assets to write.
# I0402 20:23:56.062767 139940478830336 builder_impl.py:124] No assets to write.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0402 20:24:01.338898 139940478830336 saver.py:1483] Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# I0402 20:24:02.275348 139940478830336 export.py:587] Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# I0402 20:24:02.281129 139940478830336 export.py:587] Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: None
# I0402 20:24:02.286115 139940478830336 export.py:587] Signatures INCLUDED in export for Predict: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# I0402 20:24:02.289082 139940478830336 export.py:587] Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: ['eval']
# I0402 20:24:02.292207 139940478830336 export.py:587] Signatures INCLUDED in export for Eval: ['eval']
# WARNING:tensorflow:Export includes no default signature!
# W0402 20:24:02.295289 139940478830336 tf_logging.py:161] Export includes no default signature!
# INFO:tensorflow:No assets to save.
# I0402 20:24:02.776267 139940478830336 builder_impl.py:629] No assets to save.
# INFO:tensorflow:No assets to write.
# I0402 20:24:02.782413 139940478830336 builder_impl.py:124] No assets to write.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0402 20:24:07.317484 139940478830336 saver.py:1483] Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# I0402 20:24:08.133932 139940478830336 export.py:587] Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# I0402 20:24:08.138276 139940478830336 export.py:587] Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# I0402 20:24:08.143954 139940478830336 export.py:587] Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# I0402 20:24:08.147541 139940478830336 export.py:587] Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# I0402 20:24:08.148396 139940478830336 export.py:587] Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:No assets to save.
# I0402 20:24:08.608006 139940478830336 builder_impl.py:629] No assets to save.
# INFO:tensorflow:No assets to write.
# I0402 20:24:08.614245 139940478830336 builder_impl.py:124] No assets to write.
# INFO:tensorflow:SavedModel written to: ./saved_models/1554204227/saved_model.pb
# I0402 20:24:09.082002 139940478830336 builder_impl.py:414] SavedModel written to: ./saved_models/1554204227/saved_model.pb
# b'./saved_models/1554204227'
